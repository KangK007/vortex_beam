# %% [markdown]
# # 01 Model Check
#
# Use this notebook for lightweight checks of the FVVB model, OAM spectrum, and saved run outputs. Keep thesis-grade calculations in scripts so results are reproducible.
